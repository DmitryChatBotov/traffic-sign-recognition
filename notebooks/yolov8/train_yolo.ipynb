# %%
import torch
import random
import os
import torch
import numpy as np
from ultralytics import YOLO

# %% [markdown]
# Фиксируем random_seed для воспроизводимости

# %%
RANDOM_SEED=42
random.seed(RANDOM_SEED)
os.environ["PYTHONHASHSEED"] = str(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)

# %% [markdown]
# Обучаем нейросеть

# %%
torch.cuda.empty_cache()

# %%
model = YOLO('yolov8s.pt')

# %%
epochs = 15
batch=24
image_size = 640

# %%
result = model.train(data='./output_data/traffic-sign.yaml', epochs=epochs, batch=batch, seed=RANDOM_SEED, imgsz=image_size)
# Out:
# New https://pypi.org/project/ultralytics/8.0.218 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.217 🚀 Python-3.11.0rc1 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050, 8192MiB)
# ...

# %% [markdown]
# Считаем метрики на валидации

# %%
metrics = model.val()

# %% [markdown]
# Чтобы была возможность запускать модель на мобильных устройствах, переведем ее в формат ONNX

# %%
path  =  model.export(format="onnx", imgsz=(480,640), dynamic=True)

# %%
path
